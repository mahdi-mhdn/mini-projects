# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import string
import docx
import pickle

# %%
monthbests_titles=[]
for i in range(1,60):    
    base_url=f'https://www.ketabrah.ir/d/bestsellers-in-month/page-{i}'
    response=requests.get(base_url)
    #print(response.status_code)
    html=response.content
    soup=BeautifulSoup(html,'lxml')
    titles_class=soup.find_all('a',{'class':'title'})
    unclean_titles=[t.text for t in titles_class]
    space='\u200c'
    pg_title=[]
    for t in unclean_titles:
        char=['']
        for i in t:
            if i in space:
                i=' '
                char[0]+=i
            else:
                char[0]+=i
        pg_title.append(char[0])
    monthbests_titles.extend(pg_title)
print(len(titles))
# Out:
# 2419

# %%
monthbests_titles
# Out:
# ['کتاب صوتی قدرت انضباط شخصی',
#  'کتاب صوتی معجزه سپاسگزاری',
#  'کتاب صوتی غلبه بر اهمال کاری',
#  'کتاب صوتی چهار اثر از فلورانس اسکاول شین',
#  'کتاب صوتی سالتو',
#  'کتاب صوتی احساسات منفی را خالی کنید',
#  'کتاب صوتی ماورای طبیعی شدن',
#  'کتاب صوتی فرکانس: با ارتعاشات هماهنگ شوید و به آرزوهایتان دست یابید',
#  'کتاب صوتی اثر مرکب',
#  'کتاب اول عاشق خودت باش',
#  'کتاب صوتی کتابخانه نیمه شب',
#  'کتاب صوتی آنا کارنینا',
#  'کتاب صوتی محدودیت صفر',
#  'کتاب قدرت انضباط شخصی',
#  'کتاب کتابخانه نیمه شب',
#  'کتاب صوتی آنچه در مدرسه یاد نگرفته اید',
#  'کتاب شب امتحان فارسی 3 - دوازدهم',
#  'کتاب چرا مردان زنان زیرک را دوست دارند',
#  'کتاب طرز فکر استراتژیک',
#  'کتاب صوتی ترک آسان سیگار',
#  'کتاب شب امتحان انگلیسی 3 - دوازدهم',
#  'خلاصه کتاب صوتی نیمه تاریک وجود',
#  'کتاب صوتی پاکسازی چاکراها: نیروی معنوی خود را برای آگاهی و شفا پیدا کنید',
#  'کتاب سم زدایی دوپامین',
#  'کتاب صوتی روزت را مدیریت کن',
#  'کتاب محدودیت صفر',
# ...

# %%
with open("month_bestseller_titles_list", "wb") as fp:   #Pickling
    pickle.dump(monthbests_titles, fp)

# %%
novel_titles=[]
for i in range(1,60):    
    base_url=f'https://www.ketabrah.ir/book-category/%DA%A9%D8%AA%D8%A7%D8%A8-%D8%AF%D8%A7%D8%B3%D8%AA%D8%A7%D9%86-%D8%B1%D9%85%D8%A7%D9%86/page-{i}?bt=books&sort=bestsellers'
    response=requests.get(base_url)
    #print(response.status_code)
    html=response.content
    soup=BeautifulSoup(html,'lxml')
    titles_class=soup.find_all('a',{'class':'title'})
    unclean_titles=[t.text for t in titles_class]
    space='\u200c'
    pg_title=[]
    for t in unclean_titles:
        char=['']
        for i in t:
            if i in space:
                i=' '
                char[0]+=i
            else:
                char[0]+=i
        pg_title.append(char[0])
    novel_titles.extend(pg_title)
print(len(titles))
# Out:
# 2419

# %%
novel_titles
# Out:
# ['کتاب سیزده',
#  'کتاب میدگارد 2: افسانه چشمه کوه مشرق',
#  'کتاب میدگارد 5: آخرین فرزند زمین',
#  'کتاب جیران و اسرار حرمسرای ناصر الدین شاه',
#  'کتاب میدگارد 3: افسانه چشمه کوه مشرق',
#  'کتاب میدگارد 4: نفرین مهتاب',
#  'کتاب جزء از کل',
#  'کتاب شازده کوچولو',
#  'کتاب کتابخانه نیمه شب',
#  'کتاب ملت عشق (چهل قانون عشق)',
#  'کتاب هنگامی که نیچه گریست',
#  'کتاب کیمیاگر',
#  'رمان چشم هایش',
#  'کتاب عاشقت می کنم',
#  'کتاب قلعه حیوانات',
#  'کتاب کیمیاگر',
#  'کتاب راهبی که فراری اش را فروخت',
#  'کتاب یکی پس از دیگری',
#  'کتاب مغازه ی خودکشی',
#  'کتاب کمان گیر',
#  'کتاب آذرگان (سرگذشت آب و آتش)',
#  'رمان بر باد رفته',
#  'کتاب صد سال تنهایی',
#  'کتاب شازده کوچولو',
#  'کتاب کیمیاگر',
#  'کتاب آبانگان (سرگذشت آب و آتش)',
#  'کتاب پنج قدم فاصله',
#  'کتاب سینوهه پزشک مخصوص فرعون',
#  'کتاب زنی در قاب پنجره',
#  'کتاب تو',
#  'کتاب دیانه - جلد اول',
#  'کتاب سه شنبه ها با موری',
#  'کتاب دنیای سوفی',
#  'کتاب ملت عشق (شریعت عشق)',
#  'کتاب دختری از بروکلین',
# ...

# %%
with open("novel_titles_list", "wb") as fp:   #Pickling
    pickle.dump(novel_titles, fp)

# %%
computer_titles=[]
for i in range(1,60):    
    base_url=f'https://www.ketabrah.ir/book-category/%DA%A9%D8%AA%D8%A7%D8%A8-%D8%A2%D9%85%D9%88%D8%B2%D8%B4-%DA%A9%D8%A7%D9%85%D9%BE%DB%8C%D9%88%D8%AA%D8%B1/page-{i}?bt=books&sort=bestsellers'
    response=requests.get(base_url)
    #print(response.status_code)
    html=response.content
    soup=BeautifulSoup(html,'lxml')
    titles_class=soup.find_all('a',{'class':'title'})
    unclean_titles=[t.text for t in titles_class]
    space='\u200c'
    pg_title=[]
    for t in unclean_titles:
        char=['']
        for i in t:
            if i in space:
                i=' '
                char[0]+=i
            else:
                char[0]+=i
        pg_title.append(char[0])
    computer_titles.extend(pg_title)
print(len(titles))
# Out:
# 2419

# %%
computer_titles
# Out:
# ['کتاب حل مسائل پایتون (حل 1000 برنامه - مرجع کامل)',
#  'کتاب آموزش نرم افزار صفحه گسترده Excel',
#  'کتاب ارزهای دیجیتال: بیت کوین، بلاک چین و مفاهیم پایه',
#  'کتاب مرجع کامل برنامه  نویسی پایتون',
#  'کتاب سیر تا پیاز اینستاگرام: آموزش صفر تا صد کسب درآمد از اینستاگرام',
#  'کتاب ارز دیجیتال',
#  'کتاب قدرت اینستاگرام',
#  'کتاب آموزش گام به گام تعمیرات موبایل',
#  'کتاب مبانی کامپیوتر و برنامه سازی مبتنی بر الگوریتم و فلوچارت ساخت یافته',
#  'کتاب کلید حسابداری در Excel',
#  'کتاب پایتون به زبان ساده',
#  'کتاب آموزش گام به گام برنامه نویسی پایتون',
#  'کتاب الگوریتم و فلوچارت',
#  'کتاب مجموعه سوالات چهار گزینه ای رایانه کار ICDL',
#  'کتاب طراحی تجربه  کاربری برای مبتدیان',
#  'کتاب آموزش کاملا تصویری ویندوز 10',
#  'کتاب آموزش ساخت اپلیکیشن و بازی اندروید با App Inventor',
#  'کتاب 600 برنامه ++C با حل آن ها (حل مسائل ++C - مرجع کامل)',
#  'کتاب مبانی بلاک چین: آموزش بلاک چین در 25 گام ساده',
#  'کتاب آموزش الگوریتم و فلوچارت به زبان ساده',
# ...

# %%
with open("computer_titles_list", "wb") as fp:   #Pickling
    pickle.dump(computer_titles, fp)

# %%
kid_titles=[]
for i in range(1,60):    
    base_url=f'https://www.ketabrah.ir/book-category/%DA%A9%D8%AA%D8%A7%D8%A8-%DA%A9%D9%88%D8%AF%DA%A9/page-{i}?bt=books&sort=bestsellers'
    response=requests.get(base_url)
    #print(response.status_code)
    html=response.content
    soup=BeautifulSoup(html,'lxml')
    titles_class=soup.find_all('a',{'class':'title'})
    unclean_titles=[t.text for t in titles_class]
    space='\u200c'
    pg_title=[]
    for t in unclean_titles:
        char=['']
        for i in t:
            if i in space:
                i=' '
                char[0]+=i
            else:
                char[0]+=i
        pg_title.append(char[0])
    kid_titles.extend(pg_title)
print(len(titles))
# Out:
# 2419

# %%
kid_titles
# Out:
# ['کتاب قصه های کلیله و دمنه',
#  'کتاب بهترین داستان های وقت خواب',
#  'کتاب قصه های شب برای پسر های کوچولو',
#  'کتاب قصه هایی برای شاهزاده خانم ها',
#  'کتاب قصه های شاهنامه فردوسی',
#  'کتاب آبشار جاذبه: جلد اول',
#  'کتاب قصه های شیرین مادربزرگ',
#  'کتاب داستان های ویژه برای پسران ماجراجو: 15 داستان جالب و هیجان انگیز پسرانه',
#  'کتاب شگفتی های فضا',
#  'کتاب شناخت بدن انسان برای نوجوانان',
#  'کتاب خاطرات یک بچه ی بی عرضه: حقیقت تلخ',
#  'کتاب آموزش جامع روخوانی قرآن کریم برای خردسالان و نوجوانان',
#  'کتاب قصه های شب برای دختر های کوچولو',
#  'کتاب قصه های پندآموز کهن: خرگوش باهوش و قصه های دیگر',
#  'کتاب آموزش زبان انگلیسی برای کودکان',
#  'کتاب من خوب هستم!',
#  'کتاب می خوام برم دستشویی',
#  'کتاب قصه های 3 ساله ها',
#  'کتاب ماشین ها، صدای ترسناک',
#  'کتاب من گاستون عصبانی ھستم',
#  'کتاب آموزش نماز',
#  'کتاب آواز الفبا',
#  'کتاب بچه ها بیایید نمایش 2',
#  'کتاب مجموعه داستان هایی برای تقویت هوش هیجانی در کودکان 2',
#  'کتاب قصه های 5 ساله ها',
# ...

# %%
with open("kid_titles_list", "wb") as fp:   #Pickling
    pickle.dump(kid_titles, fp)

# %%
curriculum_titles=[]
for i in range(1,60):    
    base_url=f'https://www.ketabrah.ir/book-category/%DA%A9%D8%AA%D8%A7%D8%A8-%D8%AF%D8%B1%D8%B3%DB%8C-%DA%A9%D9%85%DA%A9-%D8%A2%D9%85%D9%88%D8%B2%D8%B4%DB%8C/page-{i}?sort=bestsellers'
    response=requests.get(base_url)
    #print(response.status_code)
    html=response.content
    soup=BeautifulSoup(html,'lxml')
    titles_class=soup.find_all('a',{'class':'title'})
    unclean_titles=[t.text for t in titles_class]
    space='\u200c'
    pg_title=[]
    for t in unclean_titles:
        char=['']
        for i in t:
            if i in space:
                i=' '
                char[0]+=i
            else:
                char[0]+=i
        pg_title.append(char[0])
    curriculum_titles.extend(pg_title)
print(len(titles))
# Out:
# 2419

# %%
curriculum_titles
# Out:
# ['کتاب درک عمومی هنر',
#  'کتاب مصاحبه حضوری',
#  'کتاب شب امتحان سلامت و بهداشت دوازدهم',
#  'کتاب شب امتحان هویت اجتماعی (علوم اجتماعی) - دوازدهم',
#  'کتاب شب امتحان فارسی 3 - دوازدهم',
#  'کتاب خلاقیت تصویری و تجسمی',
#  'کتاب نقشه یک راهنما برای مبتدیان جهت تحقیق در مطالعات ترجمه',
#  'کتاب دیکته شب اول دبستان',
#  'کتاب شب امتحان شیمی 3 - دوازدهم تجربی و ریاضی',
#  'کتاب درآمدی بر ترجمه ماشینی',
#  'کتاب مجموعه سوالات هوش و اطلاعات عمومی احکام و معارف اسلامی',
#  'کتاب شب امتحان دین و زندگی 3 - دوازدهم',
#  'کتاب شب امتحان انگلیسی 3 - دوازدهم',
#  'کتاب شب امتحان علوم نهم',
#  'کتاب سوال های بسیار تاثیرگذار در مصاحبۀ استخدامی',
#  'کتاب شب امتحان ریاضی نهم',
#  'کتاب شب امتحان مطالعات اجتماعی نهم',
#  'کتاب شب امتحان زیست شناسی 3 - دوازدهم تجربی',
#  'کتاب ترجمه کتاب زبان تخصصی رشته مدیریت دولتی',
#  'کتاب شب امتحان شیمی 2 - یازدهم تجربی و ریاضی',
#  'کتاب شب امتحان فیزیک 3 - دوازدهم تجربی',
#  'کتاب شب امتحان عربی نهم',
#  'کتاب شب امتحان جغرافیای ایران - دهم',
# ...

# %%
with open("curriculum_titles_list", "wb") as fp:   #Pickling
    pickle.dump(curriculum_titles, fp)
